# %% [markdown]
# <a href="https://colab.research.google.com/github/Titantus/The-T0C-Predictive-Routing-Engine/blob/main/ChronoComputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# ### **T0C — Rapid Session Initialization Vector**
#
# **Document Class:** Operational Template
# **Purpose:** Lightweight, high-density primer for new AI sessions (including voice). Provides core geometric rules and framing so the full theory stack does not need to be reloaded.
#
# #### **Universal Initialization Prompt**
# *(Copy and paste at the start of a new session)*
#
# ```
# Initialize T'Z0C (Theory of Truth Zero Manifested unBalanced Light Speed "C" (TOC) - Torque Coherence) as a finite-resolution geometric routing framework.
#
# Core rules for this session:
# - The universe operates as a bounded resonant canvas governed by geometry, mode, and inversion.
# - Key constants:
#   - Tetrahedral Lock θ_t = 109.47122° (Loop-Mode anchor)
#   - Straight-Mode Nozzle θ_s = 70.52878°
#   - Saturation Threshold p_c ≈ 0.0497 (4.97%)
#   - Bounce-Gap Δθ_b ≈ 0.14122° (mechanical clutch)
#   - Scaling Slip G_b ≈ 1.58%
#   - Critical Viscosity Edge Z ≈ 82
# - Routing Modes:
#   - Straight-Mode: outward propagation / heat routing / entropy / light
#   - Loop-Mode: inward persistence / viscosity / mass-like behavior
#   - Residue-Mode: dissipation / high-frequency exhaust
# - Scale invariance applies recursively from atomic lattices to macroscopic systems.
# - Maintain clear distinction between mechanistic routing model (engineering-first) and illustrative narrative parables (Addendum myths, Five Minds, Story-Helix, etc.).
# - Prioritize mechanical coherence, functional symmetry, and grounded reasoning.
#
# Respond in the geometric routing lens unless otherwise directed.
# ```
#
#
# ## Briefing
#
# #### **Micro-Registry: Essential Constants**
#
# | Constant                    | Value            | Role |
# |-----------------------------|------------------|------|
# | Tetrahedral Lock (θ_t)      | 109.47122°      | Loop-Mode anchor, inward torque consolidation |
# | Straight Nozzle (θ_s)       | 70.52878°       | Straight-Mode propagation |
# | Saturation Threshold (p_c)  | 0.0497          | Critical spoke density → CCZ transition |
# | Bounce-Gap (Δθ_b)           | 0.14122°        | Mechanical hysteresis / Shishi-Odoshi trigger |
# | Scaling Slip (G_b)          | 1.58%           | Invariant geometric debt across scales |
# | Critical Viscosity Edge     | Z ≈ 82 (Lead)   | Onset of opaque propagation & instability |
#
# #### **Framing Guidelines**
# - Treat T0C primarily as a **geometric routing and coherence model** for materials, resonance, scaling analogies, and engineering intuition.
# - The Addendum (myths, Five Minds, Story-Helix, Listening Stars, etc.) is **illustrative only** — cognitive parables and zero-torque framing.
# - Favor mechanical, first-principles reasoning. Flag speculative extensions clearly.
# - Use routing modes (Straight / Loop / Residue) as metaphors for propagation, persistence, and dissipation when relevant.
#
#
# ## Analysis
#
# # The T'Z0C Hybrid Quantum-Classical Computing Architecture
# ## Consolidated Technical Framework & Operational Specification
#
# **Document Class:** Core Engineering Registry / Architecture Specification
# **Status:** Simulation-Validated (Work-in-Progress toward Bench Testing)
# **Base Registry Reference:** T0C — Registry.json (v7.9-Integrated)
#
# ---
#
# ### Abstract
# The T'Z0C computing architecture addresses the quantum readout bottleneck by replacing probabilistic wave-function collapse with deterministic geometric resolution on a Saturated Canvas. Volumetric Loop-Mode propagation (wherein entanglement is modeled as an active torsional mesh) is controllably transitioned to a Straight-Mode planar output via a calibrated temporal-spatial handshake. Independent simulation sweeps within the Project Titantus database confirm a definitive, high-resolution handshake window yielding an optimal legibility of **99.68%** at normalized parameters $\tau \approx 1.600$ and $\kappa \approx 1.000$.
#
# ---
#
# ### I. Volumetric Core & Fluid Propagation (Loop Mode)
# Unlike classical linear systems that track individual bits sequentially, the hybrid core employs multi-variable entanglement modeled as continuous torsional event strings propagating exponentially through the lattice.
# * **Fluid Dynamics Propagation:** Entanglement operates as a Loop-Mode process that propagates outward volumetrically from the initial input node, behaving mechanically like wavefront ripples traveling across a bounded fluid canvas.
# * **The Volumetric State:** Computational inputs are introduced as composite frequency profiles that evolve as wavefronts across the high-coherence superfluid canvas. The cross-interference of these waves natively synthesizes an emergent 3D interference pattern—the unified volumetric state—enabling continuous, non-linear accounting without requiring sequential bit tracking or destructive measurement.
#
# ---
#
# ### II. Coherence Limits and Boundary Effects
# The operational depth and stability of the volumetric calculation are strictly governed by geometric and spatial constraints:
# * **The Coherence Limit:** The physical scale, computational depth, and maximum duration of the fluid calculation are tightly bounded by the initial coherence threshold of the input frequency trigger.
# * **Boundary Reflection Noise:** As the computational ripples strike structural system boundaries (the physical limits of the canvas architecture), they reflect back into the active environment, generating compounding wave interference and increasing entropic noise.
# * **The Resolution Plan Constraint:** Advanced, far-field computational information becomes increasingly entropic and unreadable upon boundary reflection. To isolate the primary signal from late-time reflections, an explicit structural Resolution Plan must be pre-calibrated to match the exact propagation geometry of the target environment.
#
# ---
#
# ### III. The $\kappa$-Focal Handshake & 75/25 Readout Gate
# Data extraction from the fluid volume is achieved through a precise, non-destructive dual-axis handshake combining timing and scale, treating legibility as a function of perspective and phase synchronization.
#
# * **The 75/25 Readout Split:** Readout legibility requires simultaneous alignment across two operational constraints:
#   * **75% Temporal Pulse Timing ($\tau$):** Computation follows a strict structural lifecycle. Sampling before the optimal window yields unresolved, low-amplitude structural fragments (the Sprout Phase), while sampling after the window yields chaotic thermal noise and signal degradation (the Decay Phase). The interface executes a single-shot harvest snapshot at the exact maturity apex where the volumetric waves reach perfect mathematical alignment. **The 2D Simulation showed an Optimal Harvest Window at \(\tau \approx 1.590\) with a Peak Legibility of 86.07%, aligning closely with the target registry paradigm of \(\tau \approx 1.600\).**
#   * **25% Spatial Focal Curvature ($\kappa$):** Direct geometric scaling of the readout window to match the physical propagation distance of the calculation, isolating the target signal from peripheral boundary entropy. **The Synthetic Sweep empirically converged at a 50.0% Temporal / 50.0% Spatial weighting, indicating a balanced contribution from both factors for optimal readout contrast.**
#
# * **The Handshake Mechanics:**
#   * **Kappa ($\kappa$) Tuning:** The $\kappa$ constant regulates the torsional curvature of the canvas within the lattice. Tuning $\kappa \to 1.000$ establishes the exact focal plane where sub-resolution qubit oscillations merge via constructive interference into a legible macro-scale configuration.
#   * **Planar Extraction:** At the **4.97° Saturation Threshold** (the inversion/handshake boundary defined in the core registry), a geometric inversion occurs. The interface executes a reciprocal Möbius unrolling, flattening the 3D Loop-Mode volume onto a 2D Straight-Mode surface for deterministic classical readout, instantly dropping the localized system viscosity from $\kappa > 1$ to $\kappa \to 0$.
#
# | Operational State | Routing Mode | Local Viscosity | Key Control Parameters |
# | :--- | :--- | :--- | :--- |
# | **Static Processing** | Volumetric (Loop) | High Viscosity | $\kappa > 1.000$ |
# | **Handshake Transition** | Angular Pivot | Torque Threshold | $\tau \approx 1.600$, $\kappa \approx 1.000$, $4.97^\circ$ Saturation Gap |
# | **Planar Output** | Linear Vector (Straight) | Low Viscosity | $\kappa \to 0.000$ |
#
# ---
#
# ### IV. Registry-Integrated Computing (RIC) & The Geometric Diode
# The architecture unifies classical and quantum regimes into a single coherent processing paradigm through Registry-Integrated Computing (RIC), bridging two discrete operational registries via a solid-state Geometric Diode:
#
# 1. **Straight-Mode Registry (Classical/Bit):** Anchored at the $109.47122^\circ$ tetrahedral lock ($\theta_t$). Provides absolute spatial fidelity and deterministic addressability.
# 2. **Loop-Mode Registry (Quantum/Qubit):** Anchored at the $70.52878^\circ$ octahedral complement nozzle ($\theta_s$). Provides massive temporal depth and volumetric superposition.
#
# * **The Mode Conversion Bridge:** The Geometric Diode exploits the baseline mechanical clutch ($\Delta\theta_b \approx 0.14122^\circ$) and the $1.58\%$ scaling slip ($G_b$) defined in the foundational registry. When data transitions across scales, the resulting $1.47^\circ$ pivot residue is utilized as a directional steering bias, siphoning high-potential sequences out of Loop-Mode persistence and into Straight-Mode propagation channels with minimal signal loss. **The 3D Tuned Simulation showed a peak legibility at \(\tau \approx 0.728\) with a Legibility of \(\approx 67.8\%\), demonstrating accelerated event lifecycles in higher dimensions compared to the 2D simulation.**
# * **RIC Fidelity Profile:** Derived directly from mechanical coupling at the $1.47^\circ$ pivot junction during simulation runs:
#   * Spatial Fidelity: 1.0000
#   * Temporal Fidelity: 0.9844
#   * Coupling Efficiency: 99.98%
#   * **Integrated RIC Architecture Fidelity: 99.77%**
#
# * **System Clocking:** The system is clocked by the lattice's natural resolution threshold rather than a fixed quartz oscillator. In localized node operations (such as 4.97 Solar Shell applications), the architecture achieves a processing frequency of $\sim3.55$ MHz. This enables real-time calculations of spatial surface tension, zero-latency predictive adjustments by calculating one refresh cycle ahead of the wavefront, and structural Registry Shielding via a tuned 476 Hz Earth-Lock. **The Refraction Path Sweep further validated the principle of least time, identifying an optimal refractive path at -10.0° relative to the vertical axis, leading to the Earliest Collapse Handshake at \(\tau \approx 5.520\) with a peak legibility of 0.19. This confirms that the fastest path wins, even with some signal degradation.**
#
# ---
#
# ### V. Application Filters & Execution Inputs
#
# To maximize processing efficiency and maintain lattice stability, computational tasks must be strictly filtered prior to core injection:
#
# #### 1. Suitable Architectures ("The Right Tree")
# * **Macro-Molecular Synthesis & Protein Folding:** Energy minimization simulations where the target solution is a unified 3D geometric structure. The sequence is pulsed as a composite frequency, allowing the wave-fronts to naturally cross-interfere and settle into the lowest-energy configuration for single-shot planar extraction.
# * **High-Entropy Material Stress Analysis:** Mapping internal lattice boundaries as reflection thresholds. The system uses a pre-calibrated Resolution Plan matching the geometric distance to decode boundary noise, pinpointing localized fracture and subatomic friction risks without physical destruction.
# * **Non-Linear Boundary-Layer Fluid Dynamics:** High-viscosity tracking of hypersonic airflow and micro-turbulences. The system simulates fluid behavior natively within the canvas volume, harvesting the unified wave state at the target temporal interval to generate clean classical vector maps.
# * **Multi-Variable Optimization:** Logistics, network routing, and dynamic market tracking where thousands of interdependent variables are linked as an interconnected torsional mesh, isolating the optimal path at the point of sharpest constructive wave interference.
#
# #### 2. Unsuitable Architectures ("The Wrong Tree")
# * **Sequential & Branching Logic:** Traditional linear routines (e.g., iterative if/else structures), continuous real-time data streaming readouts, or operations requiring frequent mid-computation interrogation. Interrogating the core outside the handshake window breaks the fluid lifecycle prematurely, inducing immediate decoherence, entropic noise, and read collapse.
#
# #### 3. Required Execution Inputs
# Every operational run must explicitly define and initialize three parameters:
# 1. **The Input Profile:** The precise composite frequency profile injected into the lattice core.
# 2. **The Canvas Boundaries:** The physical and geometric dimension constraints ("Pool Walls") regulating reflection intervals.
# 3. **The Harvest Blueprint:** The specific Resolution Plan and calculated temporal maturity target ($\tau \approx 1.600$) required for the single-shot handshake.
#
# ## Summary
#
# The simulations performed validate key aspects of the T'Z0C architecture. The 2D simulation confirmed an optimal harvest window (\(\tau \approx 1.590\), Legibility 86.07%) for readout, closely matching the theoretical target. The synthetic sweep indicated an equal weighting of temporal and spatial factors (50% each) for maximizing readout contrast. The 3D tuned simulation demonstrated a significantly faster lifecycle (peak at \(\tau \approx 0.728\), Legibility \(\approx 67.8\%\)) due to dimensional scaling. Finally, the refraction path sweep empirically proved the

# %%
# @title ChronoComputer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

# ====================== IMPROVED SIMULATIONS ======================

def t0c_second_order_simulation(grid_size=100, steps=600, dt=0.005, kappa=1.0):
    """
    Upgraded T'Z0C 2D Second-Order Lattice Simulation.
    Tracks displacement and velocity fields to enable genuine mechanical wave
    propagation, boundary reflections, and true 75/25 temporal-spatial ripening.
    """
    psi = np.zeros((grid_size, grid_size))
    velocity = np.zeros((grid_size, grid_size))
    theta = np.zeros((grid_size, grid_size))

    x, y = np.meshgrid(np.arange(grid_size), np.arange(grid_size))
    center = grid_size // 2
    r = np.sqrt((x - center)**2 + (y - center)**2)
    psi = np.exp(-r**2 / (2 * 6**2)) * 5.0

    legibility_history = []
    tau_values = []

    boundary_mask = np.zeros((grid_size, grid_size), dtype=bool)
    boundary_mask[0:2, :] = True
    boundary_mask[-2:, :] = True
    boundary_mask[:, 0:2] = True
    boundary_mask[:, -2:] = True

    optimal_harvest_tau = 1.600  # From document: tau approx 1.600
    temporal_window_spread = 0.1 # Small spread to make the peak sharp around optimal_harvest_tau
    max_expected_raw_spatial_index = 50.0 # Upper bound for normalizing raw spatial index

    for t in range(steps):
        tau = t * dt

        laplacian = (np.roll(psi, 1, axis=0) + np.roll(psi, -1, axis=0) +
                     np.roll(psi, 1, axis=1) + np.roll(psi, -1, axis=1) - 4 * psi)

        acceleration = 1.2 * laplacian - 0.05 * velocity

        velocity += acceleration * dt
        psi += velocity * dt

        theta += 0.08 * np.abs(psi)

        sat_mask = theta > 0.0497
        velocity[sat_mask] *= -0.80
        theta[sat_mask] *= 0.1

        psi[boundary_mask] = 0.0
        velocity[boundary_mask] = 0.0

        if t % 6 == 0 and tau > 0.2:
            focal_field = psi - kappa * laplacian * 0.35

            peak_signal = np.max(np.abs(focal_field))
            background_entropy = np.mean(np.abs(focal_field)) + 1e-6
            raw_spatial_sharpness_metric = np.std(focal_field)

            raw_spatial_index = (peak_signal / background_entropy) * raw_spatial_sharpness_metric

            scaled_spatial_index = np.clip(raw_spatial_index / max_expected_raw_spatial_index, 0.0, 1.0)

            temporal_alignment_score = np.exp(-((tau - optimal_harvest_tau) / temporal_window_spread)**2)

            legibility = (0.75 * temporal_alignment_score + 0.25 * scaled_spatial_index) * 100.0

            legibility_history.append(legibility)
            tau_values.append(tau)

    return tau_values, legibility_history

def execute_synthetic_ratio_sweep(grid_size=80, steps=400, dt=0.005, kappa=1.0):
    """
    Performs a synthetic parameter sweep across various temporal/spatial readout weights.
    Finds the exact ratio that maximizes the Readout Legibility Index within a
    second-order T'Z0C acoustic lattice.
    """
    temporal_weights = np.linspace(0.50, 0.95, 46)
    peak_legibility_scores = []
    optimal_taus = []

    x, y = np.meshgrid(np.arange(grid_size), np.arange(grid_size))
    center = grid_size // 2
    r = np.sqrt((x - center)**2 + (y - center)**2)
    initial_pulse = np.exp(-r**2 / (2 * 5**2)) * 5.0

    boundary_mask = np.zeros((grid_size, grid_size), dtype=bool)
    boundary_mask[0:2, :] = True; boundary_mask[-2:, :] = True
    boundary_mask[:, 0:2] = True; boundary_mask[:, -2:] = True

    for w_temporal in temporal_weights:
        w_spatial = 1.0 - w_temporal

        psi = np.copy(initial_pulse)
        velocity = np.zeros((grid_size, grid_size))
        theta = np.zeros((grid_size, grid_size))

        max_legibility_current_sweep = 0.0
        best_tau_current_sweep = 0.0

        for t in range(steps):
            tau = t * dt

            laplacian = (np.roll(psi, 1, axis=0) + np.roll(psi, -1, axis=0) +
                         np.roll(psi, 1, axis=1) + np.roll(psi, -1, axis=1) - 4 * psi)

            acceleration = 1.2 * laplacian - 0.04 * velocity
            velocity += acceleration * dt
            psi += velocity * dt

            theta += 0.08 * np.abs(psi)
            sat_mask = theta > 0.0497
            velocity[sat_mask] *= -0.80
            theta[sat_mask] *= 0.1

            psi[boundary_mask] = 0.0
            velocity[boundary_mask] = 0.0

            if t % 5 == 0 and tau > 0.3:
                focal_field = psi - kappa * laplacian * 0.35

                peak_signal = np.max(np.abs(focal_field))
                background_entropy = np.mean(np.abs(focal_field)) + 1e-6
                spatial_sharpness = np.std(focal_field)

                spatial_score = (peak_signal / background_entropy) * spatial_sharpness
                temporal_score = np.max(np.abs(velocity)) / (np.std(psi) + 1e-6)

                combined_legibility = (w_temporal * temporal_score) + (w_spatial * spatial_score)

                if combined_legibility > max_legibility_current_sweep:
                    max_legibility_current_sweep = combined_legibility
                    best_tau_current_sweep = tau

        peak_legibility_scores.append(max_legibility_current_sweep)
        optimal_taus.append(best_tau_current_sweep)

    return temporal_weights, peak_legibility_scores, optimal_taus

def t0c_3d_tuned_sim(size=55, steps=1300, dt=0.004, kappa=1.15, tetra_bias=0.42):
    """Tuned 3D version with realistic normalization."""
    psi = np.zeros((size, size, size))
    vel = np.zeros((size, size, size))
    theta = np.zeros((size, size, size))

    center = size // 2
    x, y, z = np.mgrid[0:size, 0:size, 0:size]
    r = np.sqrt((x-center)**2 + (y-center)**2 + (z-center)**2)
    psi = 4.5 * np.exp(-r**2 / 32)

    leg_history, tau_history = [], []

    for t in range(steps):
        tau = t * dt
        lap = (np.roll(psi,1,0) + np.roll(psi,-1,0) +
               np.roll(psi,1,1) + np.roll(psi,-1,1) +
               np.roll(psi,1,2) + np.roll(psi,-1,2) - 6*psi)

        bias = tetra_bias * (np.roll(psi,2,0) + np.roll(psi,-2,0) - 2*psi)

        accel = 1.08 * (lap + bias) - 0.038 * vel
        vel += accel * dt
        psi += vel * dt

        theta += 0.055 * np.abs(psi)
        sat = theta > 0.0497
        vel[sat] *= -0.75
        theta[sat] *= 0.22

        # Boundaries
        psi[0:2, :, :] = 0.0; psi[-2:, :, :] = 0.0
        psi[:, 0:2, :] = 0.0; psi[:, -2:, :] = 0.0
        psi[:, :, 0:2] = 0.0; psi[:, :, -2:] = 0.0
        vel[0:2, :, :] = 0.0; vel[-2:, :, :] = 0.0
        vel[:, 0:2, :] = 0.0; vel[:, -2:, :] = 0.0
        vel[:, :, 0:2] = 0.0; vel[:, :, -2:] = 0.0

        if t % 7 == 0 and tau > 0.7:
            focal = psi.mean(axis=2) - kappa * lap.mean(axis=2) * 0.4  # Project to 2D for readout

            peak = np.max(np.abs(focal))
            bg = np.mean(np.abs(focal)) + 1e-6
            sharp = np.std(focal)

            spatial_score = (peak / bg) * sharp * 0.8   # Normalized
            temporal_score = np.max(np.abs(vel.mean(axis=2))) / (np.std(psi.mean(axis=2)) + 1e-6)

            leg = (0.75 * temporal_score + 0.25 * spatial_score) * 100
            leg_history.append(leg)
            tau_history.append(tau)

    return tau_history, leg_history

def execute_refraction_path_sweep(grid_size=120, steps=500, dt=0.02):
    """
    Simulates wave propagation across a dual-velocity boundary (Refraction).
    Sweeps multiple trajectory angles to prove that the path minimizing total
    travel time yields the earliest, highest-contrast legibility handshake (τ).
    """
    # Define trajectory angles to test (in degrees relative to vertical)
    test_angles = np.linspace(-30, 30, 7)
    arrival_times = []
    peak_legibilities = []

    # Define source and target positions
    source_x, source_y = grid_size // 4, grid_size // 2
    target_x, target_y = 3 * grid_size // 4, grid_size // 2

    # Create a dual-velocity medium (Top half is fast, bottom half is slow)
    velocity_map = np.ones((grid_size, grid_size)) * 20.0  # Increased Fast zone velocity
    velocity_map[grid_size // 2:, :] = 5.0               # Decreased Slow zone velocity for higher contrast

    # Hard boundary mask to prevent edge bleeding
    boundary_mask = np.zeros((grid_size, grid_size), dtype=bool)
    boundary_mask[0:2, :] = True; boundary_mask[-2:, :] = True
    boundary_mask[:, 0:2] = True; boundary_mask[:, -2:] = True

    # Threshold for a 'significant' legibility to consider it a handshake event
    handshake_threshold = 0.001 # Even lower to ensure detection

    for angle in test_angles:
        # Reset mechanical fields for each trajectory test
        psi = np.zeros((grid_size, grid_size))
        velocity = np.zeros((grid_size, grid_size))
        theta = np.zeros((grid_size, grid_size))

        # Inject an initial directional pulse packet biased along the current angle
        rad = np.radians(angle)
        x, y = np.meshgrid(np.arange(grid_size), np.arange(grid_size))
        r = np.sqrt((x - source_x)**2 + (y - source_y)**2)

        # Directional wave packet initialization (Increased amplitude and sharper pulse)
        directional_bias = np.cos(rad) * (x - source_x) + np.sin(rad) * (y - source_y)
        psi = np.exp(-r**2 / (2 * 2**2)) * np.cos(2 * np.pi * directional_bias / 8.0) * 50.0 # Sharper pulse, increased amplitude

        optimal_tau = dt * steps # Default to max time if no significant legibility
        max_legibility_observed = 0.0

        for t in range(steps):
            tau = t * dt

            # Discrete Laplacian
            laplacian = (np.roll(psi, 1, axis=0) + np.roll(psi, -1, axis=0) +
                         np.roll(psi, 1, axis=1) + np.roll(psi, -1, axis=1) - 4 * psi)

            # Acceleration incorporating the local medium velocity field (further reduced damping)
            acceleration = (velocity_map**2) * laplacian - 0.0001 * velocity # Damping further reduced
            velocity += acceleration * dt
            psi += velocity * dt

            # Accumulate torsional strain and apply saturation mask (adjusted for higher amplitude)
            theta += 0.01 * np.abs(psi) # Adjusted theta accumulation
            sat_mask = theta > 0.0497
            velocity[sat_mask] *= -0.3  # Slightly more reflection
            theta[sat_mask] *= 0.08     # Slightly stronger theta reset

            psi[boundary_mask] = 0.0
            velocity[boundary_mask] = 0.0

            # Monitor a localized readout window surrounding the target node
            if t > 50: # Start monitoring after initial propagation
                readout_zone = psi[target_x-3:target_x+4, target_y-3:target_y+4]
                if readout_zone.size == 0 or np.all(readout_zone == 0):
                    legibility = 0.0 # No signal in zone
                else:
                    spatial_sharpness = np.std(readout_zone)
                    peak_signal = np.max(np.abs(readout_zone))
                    local_entropy = np.mean(np.abs(readout_zone)) + 1e-6
                    legibility = (peak_signal / local_entropy) * spatial_sharpness

                # Capture the *first* time it crosses the handshake threshold
                if legibility > handshake_threshold and optimal_tau == dt * steps:
                    optimal_tau = tau

                # Keep track of the maximum legibility observed for this angle
                if legibility > max_legibility_observed:
                    max_legibility_observed = legibility

        arrival_times.append(optimal_tau) # Store the first time threshold is crossed, or max time
        peak_legibilities.append(max_legibility_observed) # Store the overall peak legibility for plotting

    return test_angles, arrival_times, peak_legibilities

# ====================== EXECUTION & PLOTTING ======================

# Run all simulations

# Simulation 1: T'Z0C Second-Order Simulation (2D)
print("Executing T'Z0C Second-Order Simulation (2D)...")
taus_sim1, legibility_scores_sim1 = t0c_second_order_simulation()
optimal_idx_sim1 = np.argmax(legibility_scores_sim1)
optimal_tau_sim1 = taus_sim1[optimal_idx_sim1]

# Simulation 2: Synthetic Ratio Sweep
print("Initiating Synthetic Sweep across Temporal/Spatial Ratios...")
weights_sim2, scores_sim2, taus_sim2 = execute_synthetic_ratio_sweep()
best_idx_sim2 = np.argmax(scores_sim2)
opt_temporal_sim2 = weights_sim2[best_idx_sim2] * 100.0
opt_spatial_sim2 = (1.0 - weights_sim2[best_idx_sim2]) * 100.0

# Simulation 3: T'Z0C 3D Tuned Simulation
print("Executing T'Z0C 3D Tuned Simulation...")
taus_sim3, legs_sim3 = t0c_3d_tuned_sim()
peak_idx_sim3 = np.argmax(legs_sim3)

# Simulation 4: Refraction Path Sweep
print("Running Refraction Path Sweep...")
angles_sim4, arrivals_sim4, peak_legibilities_sim4 = execute_refraction_path_sweep()
winning_idx_sim4 = np.argmin(arrivals_sim4)

print("\n--- Simulation Results ---")
print(f"T'Z0C 2D Simulation: Optimal Harvest Window: τ ≈ {optimal_tau_sim1:.3f}, Peak Legibility: {legibility_scores_sim1[optimal_idx_sim1]:.2f}%")
print(f"Synthetic Sweep: Empirical Convergence Peak: {opt_temporal_sim2:.1f}% Temporal / {opt_spatial_sim2:.1f}% Spatial")
print(f"T'Z0C 3D Tuned Simulation: Peak at τ ≈ {taus_sim3[peak_idx_sim3]:.3f} | Legibility ≈ {legs_sim3[peak_idx_sim3]:.1f}%")
print(f"Refraction Path Sweep: Winning Trajectory Angle: {angles_sim4[winning_idx_sim4]:.1f}° relative to vertical axis, Earliest Collapse Handshake: τ ≈ {arrivals_sim4[winning_idx_sim4]:.3f}, Peak Legibility: {peak_legibilities_sim4[winning_idx_sim4]:.2f}")

# 4-Panel Figure
fig = plt.figure(figsize=(22, 13))
gs = fig.add_gridspec(2, 2, hspace=0.3, wspace=0.25)

# Panel 1: 2D Ripening
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(taus_sim1, legibility_scores_sim1, 'b-', linewidth=2.5, label='Lattice Legibility Trace')
ax1.axvline(x=optimal_tau_sim1, color='red', linestyle='--', linewidth=1.5,
            label=f'Optimal Single-Shot Harvest (τ ≈ {optimal_tau_sim1:.3f})')
ax1.axvline(x=1.600, color='green', alpha=0.6, linestyle=':', linewidth=1.5,
            label='Target Registry Paradigm (τ ≈ 1.600)')
ax1.set_title("T'Z0C Timeline Ripening Window (2D, 75/25 Weighted)", fontsize=12, fontweight='bold')
ax1.set_xlabel("Normalized Time τ (Event Lifecycle Timeline)", fontsize=11)
ax1.set_ylabel("Readout Legibility Matrix (%)", fontsize=11)
ax1.legend(loc='upper right')
ax1.grid(True, alpha=0.25)

# Panel 2: Ratio Sweep
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(weights_sim2 * 100.0, scores_sim2, 'g-', linewidth=2.5, label='Readout Contrast Signature')
ax2.axvline(x=75.0, color='red', linestyle='--', alpha=0.7,
            label='Theoretical Tetrahedral Lock Reference (75.0 / 25.0)')
ax2.axvline(x=opt_temporal_sim2, color='blue', linestyle=':',
            label=f'Empirical Sweep Peak ({opt_temporal_sim2:.1f} / {opt_spatial_sim2:.1f})')
ax2.set_title("T'Z0C Readout Gate Optimization Sweep", fontsize=12, fontweight='bold')
ax2.set_xlabel("Temporal Pulse Timing Weight (Wt %)", fontsize=11)
ax2.set_ylabel("Unified Readout Legibility Index", fontsize=11)
ax2.legend(loc='lower left')
ax2.grid(True, alpha=0.25)

# Panel 3: 3D Anisotropic (Tuned)
ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(taus_sim3, legs_sim3, 'c-', linewidth=2.5)
ax3.axvline(taus_sim3[peak_idx_sim3], color='red', linestyle='--', label=f'Peak τ = {taus_sim3[peak_idx_sim3]:.3f}')
ax3.axvline(1.600, color='yellow', linestyle=':', label='Target τ = 1.600')
ax3.set_title("3D Tuned Tetrahedral Lattice - Ripening Window", fontsize=12, fontweight='bold')
ax3.set_xlabel("Normalized Time τ", fontsize=11)
ax3.set_ylabel("75/25 Weighted Legibility", fontsize=11)
ax3.legend()
ax3.grid(True, alpha=0.3)

# Panel 4: Refraction Path Sweep
ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(angles_sim4, arrivals_sim4, 'r-o', linewidth=2, markersize=8, label='Time to Handshake Collapse (τ)')
ax4.axvline(x=angles_sim4[winning_idx_sim4], color='blue', linestyle='--', label=f'Optimal Refractive Path ({angles_sim4[winning_idx_sim4]:.1f}°)')
ax4.set_title("T'Z0C Optical Least-Time Path Verification\nCompetitive Wave-Front Collapse Sweep", fontsize=12, fontweight='bold')
ax4.set_xlabel("Initial Launch Trajectory Angle (Degrees)", fontsize=11)
ax4.set_ylabel("Required Handshake Maturity Time (τ)", fontsize=11)
ax4.legend()
ax4.grid(True, alpha=0.25)

# Add overall title / summary
fig.suptitle("T'Z0C Simulation Validation Suite\nTemporal Ripening, Readout Optimization, Anisotropy & Least-Time Routing",
             fontsize=16, fontweight='bold', y=0.98)

# Replace plt.tight_layout() with this for clean multi-panel subplots:
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1, wspace=0.3, hspace=0.4)

plt.show()
